# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
import os
RESEARCH_DIR = "/content/drive/MyDrive/Pothole/models/research"

# %%
os.chdir(RESEARCH_DIR)

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Pothole/models/research'

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global step 97508: loss = 0.0238 (0.139 sec/step)
# I1214 07:44:45.152548 140372580243328 learning.py:507] global step 97508: loss = 0.0238 (0.139 sec/step)
# INFO:tensorflow:global step 97509: loss = 0.0338 (0.159 sec/step)
# I1214 07:44:45.313346 140372580243328 learning.py:507] global step 97509: loss = 0.0338 (0.159 sec/step)
# INFO:tensorflow:global step 97510: loss = 0.0340 (0.150 sec/step)
# I1214 07:44:45.464737 140372580243328 learning.py:507] global step 97510: loss = 0.0340 (0.150 sec/step)
# INFO:tensorflow:global step 97511: loss = 0.0319 (0.126 sec/step)
# I1214 07:44:45.591966 140372580243328 learning.py:507] global step 97511: loss = 0.0319 (0.126 sec/step)
# INFO:tensorflow:global step 97512: loss = 0.0580 (0.146 sec/step)
# I1214 07:44:45.739391 140372580243328 learning.py:507] global step 97512: loss = 0.0580 (0.146 sec/step)
# INFO:tensorflow:global step 97513: loss = 0.0491 (0.152 sec/step)
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_coco.config --trained_checkpoint_prefix training/model.ckpt-98043 --output_directory potholes_model
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Pothole/models/research/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Pothole/models/research/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:197: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...
